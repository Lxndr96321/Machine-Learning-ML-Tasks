# %% [markdown]
# ### Adding text to Image

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from matplotlib import image
from PIL import ImageDraw, ImageFont
from PIL import Image

# %% [markdown]
# ### creating an empty canvas

# %%
Netflix = Image.new(mode = 'RGB', size = (399, 186), color = (0,0,0))

# %%
plt.imshow(Netflix)

# %% [markdown]
# ### first create an object

# %%
NetflixWrite = ImageDraw.Draw(Netflix)

# %%
NetWrite = ImageFont.truetype(r"C:\Users\Manikanta\Downloads\Font\Roboto-Bold.ttf", size = 50)

# %%
NetflixWrite.text((100, 75), text = 'NETFLIX',font = NetWrite, fill = (229, 9, 20))

# %%
plt.imshow(Netflix)
