# %%
import numpy as np, matplotlib.pyplot as plt, seaborn as sns, matplotlib.image as image

# %%
x = np.zeros((50,50,3), dtype = 'uint8')
plt.imshow(x)

# %%
x[:,:]= [229, 9, 20]
plt.imshow(x)

# %%
rover = plt.imread(r'C:\Users\Sonu Vikas\Desktop\AIMLDL\range-rover-sv-carmel-edition-2022-luxury-suv-5k-wallpaper-1920x1080-10wallpaper.com.jpg')
print(type(rover), rover.shape, rover.size, rover.ndim, sep = '\n')
# Out:
# <class 'numpy.ndarray'>
# (1080, 1920, 3)
# 6220800
# 3

# %%
plt.imshow(rover)

# %%
# splitting the image int its respective color channels
roverRed, roverGreen, roverBlue = rover[:,:,0], rover[:,:,1], rover[:,:,2]

# %%
plt.imshow(roverRed)

# %%
plt.imshow(roverBlue)

# %%
# flip
plt.imshow(np.flip(rover))

# %%
rover1,rover2, rover3, rover4 = np.flip(rover), np.flip(rover, axis = 0), np.flip(rover, axis = 1), np.flip(rover, axis = -1)
roverlr, rovernud = np.fliplr(rover), np.flipud(rover)

# %%
fig, ax = plt.subplots(2, 3)
ax[0,0].imshow(rover1)
ax[0,1].imshow(rover2)
ax[0,2].imshow(rover3)
ax[1,0].imshow(rover4)
ax[1,1].imshow(roverlr)
ax[1,2].imshow(rovernud)

# %%
# roll 
x = np.random.randint(1,100, (3,2,2))
x
# Out:
# array([[[35, 67],
#         [ 7, 61]],
#
#        [[86, 67],
#         [54, 23]],
#
#        [[39, 43],
#         [81, 25]]])

# %%
np.roll(x, 1)
# Out:
# array([[[25, 35],
#         [67,  7]],
#
#        [[61, 86],
#         [67, 54]],
#
#        [[23, 39],
#         [43, 81]]])

# %%
np.roll(x, 1, axis = 0)
# Out:
# array([[[39, 43],
#         [81, 25]],
#
#        [[35, 67],
#         [ 7, 61]],
#
#        [[86, 67],
#         [54, 23]]])

# %%
np.roll(x,1, axis = -1)
# Out:
# array([[[67, 35],
#         [61,  7]],
#
#        [[67, 86],
#         [23, 54]],
#
#        [[43, 39],
#         [25, 81]]])

# %%
plt.imshow(np.roll(rover, 512, axis=0))
